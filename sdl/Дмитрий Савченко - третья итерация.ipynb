# %% [markdown]
# <font color='blue' size=5><b>Комментарий ревьюера</b></font>
#
# <font color='blue'>Привет, Дмитрий! Меня зовут Григорий Звездин, и я буду проверять этот проект. Спасибо за проделанную работу! Предлагаю общаться на «ты».</font>
#
# <font color='blue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font>
#
#
# ---
#
#
# <font color='blue'>синий текст - просто текст комментария</font>
#
# <font color='green'>✔️ и зеленый текст - все отлично</font>
#
# <font color='orange'>⚠️ и оранжевый текст - сделано все правильно, однако есть рекомендации, на что стоит обратить внимание</font>
#
# <font color='red'>❌ и красный текст - есть недочеты</font>
#
#
# ---
#
# <font color='blue'>Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты, а также сразу увидеть исправленное. </font>
#
# Ответы на мои комментарии лучше тоже помечать.
# Например: <font color='blue'><b>Комментарий студента</b></font>
#
# <font color='blue'><b>Давай смотреть, что получилось!</b></font>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Предисловие:</b>
# <p>Привет</p>
# <p>т.к. в Я.Практикуме последнюю тему решили нориально не давать, я Х.З., что тут нужно делать и как правильно, будем разбираться вместе))</p>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Теперь вопрос правильно я преобразование сделал из картинки в вектор или нет:</b>
# <p>Загрузчик я сделал, но сильно сомневаюсь, что правльно связал имена картинок и их вектор</p>
# <p>И модель теперь вообще не понимает что я ей показываю=)))</p>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Я не умею исользовать Керас:</b>
#
# <p>Много раз пишу о том что я ХЗ как предсказывать оценку что-то написал но оно не работает как делать не знаю</p>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Результаты скорее случайные:</b>
#
# <p>Добиться вывода разных картинок удалось, но это скорее случайность чем система</p>
# <p>Спасибо за подсказки, они были очень полезны.</p>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера v2: </b></font> ✔️\
# <font color='green'>Привет! Давай смотреть\
# Мои комментарии в этой итерации будут отмечены версией v2

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Хорошо, вперед :)

# %% [markdown]
# # Прекод
#
# # Сборный проект-4
#
# Вам поручено разработать демонстрационную версию поиска изображений по запросу.
#
# Для демонстрационной версии нужно обучить модель, которая получит векторное представление изображения, векторное представление текста, а на выходе выдаст число от 0 до 1 — покажет, насколько текст и картинка подходят друг другу.
#
# ### Описание данных
#
# Данные лежат в папке `/datasets/image_search/`.
#
# В файле `train_dataset.csv` находится информация, необходимая для обучения: имя файла изображения, идентификатор описания и текст описания. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `train_images` содержатся изображения для тренировки модели.
#
# В файле `CrowdAnnotations.tsv` — данные по соответствию изображения и описания, полученные с помощью краудсорсинга. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
# 3. Доля людей, подтвердивших, что описание соответствует изображению.
# 4. Количество человек, подтвердивших, что описание соответствует изображению.
# 5. Количество человек, подтвердивших, что описание не соответствует изображению.
#
# В файле `ExpertAnnotations.tsv` содержатся данные по соответствию изображения и описания, полученные в результате опроса экспертов. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
#
# 3, 4, 5 — оценки трёх экспертов.
#
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью.
#
# В файле `test_queries.csv` находится информация, необходимая для тестирования: идентификатор запроса, текст запроса и релевантное изображение. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `test_images` содержатся изображения для тестирования модели.

# %% [markdown]
# ## 1. Исследовательский анализ данных
#
# Наш датасет содержит экспертные и краудсорсинговые оценки соответствия текста и изображения.
#
# В файле с экспертными мнениями для каждой пары изображение-текст имеются оценки от трёх специалистов. Для решения задачи вы должны эти оценки агрегировать — превратить в одну. Существует несколько способов агрегации оценок, самый простой — голосование большинства: за какую оценку проголосовала большая часть экспертов (в нашем случае 2 или 3), та оценка и ставится как итоговая. Поскольку число экспертов меньше числа классов, может случиться, что каждый эксперт поставит разные оценки, например: 1, 4, 2. В таком случае данную пару изображение-текст можно исключить из датасета.
#
# Вы можете воспользоваться другим методом агрегации оценок или придумать свой.
#
# В файле с краудсорсинговыми оценками информация расположена в таком порядке:
#
# 1. Доля исполнителей, подтвердивших, что текст **соответствует** картинке.
# 2. Количество исполнителей, подтвердивших, что текст **соответствует** картинке.
# 3. Количество исполнителей, подтвердивших, что текст **не соответствует** картинке.
#
# После анализа экспертных и краудсорсинговых оценок выберите либо одну из них, либо объедините их в одну по какому-то критерию: например, оценка эксперта принимается с коэффициентом 0.6, а крауда — с коэффициентом 0.4.
#
# Ваша модель должна возвращать на выходе вероятность соответствия изображения тексту, поэтому целевая переменная должна иметь значения от 0 до 1.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Когда прогонял у себя, добавлял:
# ```
# ! pip install gensim -U
# ! curl https://code.s3.yandex.net/datasets/dsplus_integrated_project_4.zip --output data.zip
# ! unzip -o -q /content/data.zip
# ! mv to_upload source
# ```
#
# Только в последних версия gensim есть vector_size, до этого был просто size\
# А загрузка позволяет вручную в колаб не подгружать данные

# %%
# То что читал попутно
# https://thinkingneuron.com/how-to-classify-text-using-word2vec/
# https://builtin.com/machine-learning/nlp-word2vec-python
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import minmax_scale
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

import re

import nltk

from nltk.corpus import stopwords as nltk_stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')

english_stopwords = set(nltk_stopwords.words('english'))
null_stopwords = []
vect = CountVectorizer()
tf_vect = TfidfVectorizer()

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dmitry/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/dmitry/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/dmitry/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/dmitry/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Круто, что указываешь, какие материалы изучал в процессе. Такие комментарии полезны\
#     А вот комменты с неиспользуемым кодом лучше убрать

# %%
from gensim.models import Word2Vec
import numpy as np
import copy
# https://russianblogs.com/article/37751553118/
# https://medium.com/@nina95dan/simple-image-classification-with-resnet-50-334366e7311a
from PIL import Image
import matplotlib.pyplot as plt
from pathlib import Path

import sklearn.linear_model as lm
from sklearn.model_selection import GroupShuffleSplit

# %%
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, Flatten, Dense, AveragePooling2D, MaxPooling2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import InverseTimeDecay
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
# Out:
# 2022-09-16 21:17:31.677786: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Читаем данные именуем столбцы
df_t = pd.read_csv('source/train_dataset.csv')
df_c = pd.read_csv('source/CrowdAnnotations.tsv', sep='\t', names=['image', 'query_id', 'proc', 't', 'f'])
df_e = pd.read_csv('source/ExpertAnnotations.tsv', sep='\t', names=['image', 'query_id', 'e1', 'e2', 'e3'])

#display('Датасет для тернировки')
#display(df_t.head(5))
#display(df_t.info())
#display('Датасет оценок краудсорсинга')
#display(df_c.head(5))
#display(df_c.info())
#display('Датасет оценок экспертов')
#display(df_e.head(5))
#display(df_e.info())

# %% [markdown]
# __Вывод:__ Из выше представленных данных видно, что типы данных определились верно, пустые строки отсутствуют.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'>Добавь, пожалуйста, изучение данных, хотя бы посмотреть первые строки и инфо
#
# <div class="alert alert-block alert-info"><b>Комментарий студента V1:</b>
# <p>Добавил.</p></div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера v2: </b></font> ✔️\
# <font color='green'>Хорошо

# %%
# Функция покажет количество уникальных оценок в датасете
def len_list_in_col(row:pd.Series)->int:
    result = len(set(row))
    return result
# Возьмём предложенный метод
df_e['el'] = df_e[['e1', 'e2', 'e3']].values.tolist()
df_e['el'] = df_e['el'].apply(len_list_in_col)
df_e = df_e[df_e['el']!=3].copy()
df_e['em'] = df_e[['e1', 'e2', 'e3']].mode(axis=1)[0]
# Ну всё оценки экспертов лежат в столбце em
df_e
# Out:
#                           image                     query_id  e1  e2  e3  el  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2   1   1   1   1
# 1     1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2   1   1   2   2
# 2     1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2   1   1   2   2
# 3     1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2   1   2   2   2
# 4     1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2   1   1   2   2
# ...                         ...                          ...  ..  ..  ..  ..
# 5817   997722733_0cb5439472.jpg  2981702521_2459f2c1c4.jpg#2   1   1   1   1
# 5818   997722733_0cb5439472.jpg  2985679744_75a7102aab.jpg#2   1   1   1   1
# 5819   997722733_0cb5439472.jpg  3150742439_b8a352e1e0.jpg#2   1   1   2   2
# 5820   997722733_0cb5439472.jpg  3375070563_3c290a7991.jpg#2   1   1   1   1
# 5821   997722733_0cb5439472.jpg   486917990_72bd4069af.jpg#2   3   3   3   1
#
#       em
# 0      1
# 1      1
# 2      1
# 3      2
# 4      1
# ...   ..
# 5817   1
# 5818   1
# 5819   1
# 5820   1
# 5821   3
#
# [5696 rows x 7 columns]

# %%
# т.к. думать лень рашим в лоб, преобразуем оценки людей в эквивалент экспертных
converter_crowd_to_expert = {
    '[3, 0]':4,
    '[2, 1]':3,
    '[1, 2]':2,
    '[0, 3]':1
}

def crowd_to_exp(row:pd.Series, conv)->int:
    result = conv.get(str(row), None)
    return result
df_c['em'] = df_c[['t', 'f']].values.tolist()
df_c['em'] = df_c['em'].apply(crowd_to_exp,  **{'conv':converter_crowd_to_expert})

# Объеденим оценки экспертов и еще какието в один столбец
df_m = pd.merge(df_e, df_c, how='inner', on=['image','query_id'])
df_m['em_a'] = df_m['em_x'] * .6 + df_m['em_y'] * .4
# Преобразую всё что могу к значениям 0, 1
df_m['scaler_em_a'] = minmax_scale(df_m['em_a'], feature_range=(0, 1))
df_m['scaler_em_x'] = minmax_scale(df_m['em_x'], feature_range=(0, 1))
df_m['scaler_em_y'] = minmax_scale(df_m['em_y'], feature_range=(0, 1))

df_m
# Out:
#                           image                     query_id  e1  e2  e3  el  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2   1   1   1   1
# 1     1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2   1   1   2   2
# 2     1056338697_4f7d7ce270.jpg   434792818_56375e203f.jpg#2   1   1   2   2
# 3     1084040636_97d9633581.jpg   256085101_2c2617c5d0.jpg#2   2   3   3   2
# 4     1084040636_97d9633581.jpg  3396157719_6807d52a81.jpg#2   1   2   2   2
# ...                         ...                          ...  ..  ..  ..  ..
# 2253   979383193_0a542a059d.jpg  3244747165_17028936e0.jpg#2   2   2   2   1
# 2254   979383193_0a542a059d.jpg  3482062809_3b694322c4.jpg#2   1   2   2   2
# 2255   997722733_0cb5439472.jpg  2985679744_75a7102aab.jpg#2   1   1   1   1
# 2256   997722733_0cb5439472.jpg  3150742439_b8a352e1e0.jpg#2   1   1   2   2
# 2257   997722733_0cb5439472.jpg   486917990_72bd4069af.jpg#2   3   3   3   1
#
#       em_x      proc  t  f  em_y  em_a  scaler_em_a  scaler_em_x  scaler_em_y
# 0        1  0.000000  0  3   1.0   1.0     0.000000     0.000000     0.000000
# 1        1  0.000000  0  3   1.0   1.0     0.000000     0.000000     0.000000
# 2        1  0.000000  0  3   1.0   1.0     0.000000     0.000000     0.000000
# 3        3  0.333333  1  2   2.0   2.6     0.533333     0.666667     0.333333
# 4        2  0.000000  0  3   1.0   1.6     0.200000     0.333333     0.000000
# ...    ...       ... .. ..   ...   ...          ...          ...          ...
# 2253     2  0.000000  0  3   1.0   1.6     0.200000     0.333333     0.000000
# 2254     2  0.000000  0  3   1.0   1.6     0.200000     0.333333     0.000000
# 2255     1  0.000000  0  3   1.0   1.0     0.000000     0.000000     0.000000
# 2256     1  0.000000  0  3   1.0   1.0     0.000000     0.000000     0.000000
# 2257     3  0.333333  1  2   2.0   2.6     0.533333     0.666667     0.333333
#
# [2258 rows x 15 columns]

# %% [markdown]
# ## 2. Проверка данных
#
# В некоторых странах, где работает ваша компания, действуют ограничения по обработке изображений: поисковым сервисам и сервисам, предоставляющим возможность поиска, запрещено без разрешения родителей или законных представителей предоставлять любую информацию, в том числе, но не исключительно тексты, изображения, видео и аудио, содержащие описание, изображение или запись голоса детей. Ребёнком считается любой человек, не достигший 16 лет.
#
# В вашем сервисе строго следуют законам стран, в которых работают. Поэтому при попытке посмотреть изображения, запрещённые законодательством, вместо картинок показывается дисклеймер:
#
# > This image is unavailable in your country in compliance with local laws
# >
#
# Однако у вас в PoC нет возможности воспользоваться данным функционалом. Поэтому все изображения, которые нарушают данный закон, нужно удалить из обучающей выборки.

# %%
# Мои стоп слова
my_stop = ['boy', 'child', 'girl', 'baby', 'todler', 'kid']
# Лемматизация с моими стоп словами нужна для маркировки стоп лов знаком 16+
def get_lemm_word(sentence:str, stop_words:list, stop_words_my:list)->str:
    lemm_word_list = []
    sentence = re.sub(r'[^\w\s]', '', sentence).lower()
    word_list = nltk.word_tokenize(sentence)
    for word in word_list:
        lemm_word = lemmatizer.lemmatize(word)
        lemm_word_list.append(lemm_word)
    lemm_word_list = set(lemm_word_list) - set(stop_words)
    result = ' '.join(list(lemm_word_list))
    for word in stop_words_my:
        if word in result:
            result = '16+'
            break
    return result

# Основной лемматизатор
def lemmer(sentence:str, stop_words:list)->str:
    lemm_word_list = []
    word_list = nltk.word_tokenize(sentence)
    for word in word_list:
        lemm_word = lemmatizer.lemmatize(word.lower())
        in_stop_words=False
        for m in stop_words:
            if m == lemm_word:
                in_stop_words = True
                break
        if in_stop_words == False:
            lemm_word_list.append(lemm_word)
    result = ' '.join(list(lemm_word_list))
    return result

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Хорошо, и слова выбраны верно. Можно добавить в список baby, todler, kid

# %%
df_t['lemm'] = df_t['query_text'].apply(get_lemm_word, **{'stop_words':english_stopwords,
                                                         'stop_words_my':my_stop})

df_t['query_clean'] = df_t['query_text'].str.replace(r'[^\w\s]', '').str.lower()

df_t['query_clean_lemm'] = df_t['query_clean'].apply(lemmer, **{'stop_words':english_stopwords})
# Out:
# /var/folders/5m/zj2yj9bd5m55jbrzd0_nfd6m0000gn/T/ipykernel_8139/1613038779.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_t['query_clean'] = df_t['query_text'].str.replace(r'[^\w\s]', '').str.lower()

# %% [markdown]
# ## 3. Векторизация изображений
#
# Перейдём к векторизации изображений.
#
# Самый примитивный способ — прочесть изображение и превратить полученную матрицу в вектор. Такой способ нам не подходит: длина векторов может быть сильно разной, так как размеры изображений разные. Поэтому стоит обратиться к свёрточным сетям: они позволяют "выделить" главные компоненты изображений. Как это сделать? Нужно выбрать какую-либо архитектуру, например ResNet-18, посмотреть на слои и исключить полносвязные слои, которые отвечают за конечное предсказание. При этом можно загрузить модель данной архитектуры, предварительно натренированную на датасете ImageNet.

# %%
# https://russianblogs.com/article/37751553118/
paths = Path('source/train_images').rglob('*.jpg')
paths_img_for_test = Path('source/test_images').rglob('*.jpg')
# Получим в список пути картинок
jpg_paths = list(map(str, paths))
jpg_paths_img_for_test = list(map(str, paths_img_for_test))

# %%
# Получаем картинки в вектор
def img_to_vec_2(img_path:str, w, h):
    im_name = img_path.split('/')[-1]
    wh = width_img
    ht = height_img
    m = np.array(Image.open(path).convert('RGB').resize((wh,ht)))
    return im_name, m.reshape(1,wh,ht,3)

# Та функция которая по идее получает вектора изображений но по какойто причине они почти все одинаковые
vector_len_for_img_and_text = 300
def create_model(input_shape):
    backbone = ResNet50(input_shape=input_shape, weights='imagenet', include_top=False)
    model = Sequential()
    model.add(backbone)
    model.add(Dense(vector_len_for_img_and_text, activation='relu'))
    return model

def create_model_2_old(input_shape):
    backbone = ResNet50(input_shape=input_shape, weights='imagenet', include_top=False)
    model = Sequential()
    model.add(backbone)
    model.add(Flatten())
    model.add(Dense(vector_len_for_img_and_text, activation='relu'))
    return model

# Модель котораую предложил ты.
def create_model_2_r(input_shape):
    backbone = ResNet50(input_shape=input_shape, weights='imagenet', include_top=False)
    model = Sequential()
    model.add(backbone)
    model.add(Flatten())
    return model
# Возьму модель Кирилла т.к. с субботы выпытывал её у него.
def create_model_2(input_shape):
    backbone = ResNet50(input_shape=input_shape, weights='imagenet', include_top=False)
    model = Sequential()
    model.add(backbone)
    model.add(GlobalAveragePooling2D())
    return model

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера v2: </b></font> ❌\
# <font color='red'>Почти верно, но, как я писал до этого, нам не нужен полносвязный слой\
# Итог получается такой:
# ```python
# def create_model_2(input_shape):
#     backbone = ResNet50(input_shape=input_shape, weights='imagenet', include_top=False)
#     model = Sequential()
#     model.add(backbone)
#     model.add(Flatten())
#     return model
# ```
# <div class="alert alert-block alert-info"><b>Это проблема на самом деле V2:</b>
# <p>Кирилл Талалаев (преподаватель) и ты дают противоположенные функции для решения этой проблемы)))</p>
# <p>Преподаватель сказал мне что Flatten не нужен</p></div>
#
# ```python
# def create_model_2(input_shape):
#     backbone = ResNet50(input_shape=input_shape, weights='imagenet', include_top=False)
#     backbone.trainable = False
#     model = Sequential()
#     model.add(backbone)
#     model.add(GlobalAveragePooling2D())
#     return model
# ```

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера v3: </b></font> ✔\
# <font color='green'>Можно и так, и так, и GlobalMaxPooling2D. Хорошо, давай остановимся на варианте Кирилла

# %%
'''width_img = height_img = 224
img_vec = dict()
model = create_model((width_img, height_img, 3))
for path in jpg_paths:
    n, v = img_to_vec_2(path, width_img, height_img)
    r50_v = model(v)
    img_vec[n] = r50_v.numpy()[0]
print('Part test')
img_vec_2 = dict()
for path in jpg_paths_img_for_test:
    n, v = img_to_vec_2(path, width_img, height_img)
    r50_v = model(v)
    img_vec_2[n] = r50_v.numpy()[0]'''
# Out:
# "width_img = height_img = 224\nimg_vec = dict()\nmodel = create_model((width_img, height_img, 3))\nfor path in jpg_paths:\n    n, v = img_to_vec_2(path, width_img, height_img)\n    r50_v = model(v)\n    img_vec[n] = r50_v.numpy()[0]\nprint('Part test')\nimg_vec_2 = dict()\nfor path in jpg_paths_img_for_test:\n    n, v = img_to_vec_2(path, width_img, height_img)\n    r50_v = model(v)\n    img_vec_2[n] = r50_v.numpy()[0]"

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'>
#     Имеет смысл воспользоваться загрузчиком из темы Компьютерное зрение в Keras - Загрузчики данных\
#     У тебя есть полносвязные слои, а нам нужна свертка (верхушка не нужна). Параметр include_top=False убирает верхушку самого реснета, значит, тебе нужно убрать все, кроме backbone, и будет отлично (тема ResNet в Keras [GPU] про параметры модели)

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Загрузчик V1:</b>
# <p>Создал загрузчик, читает данные из нужной папки.</p>
# <p>Связывает имена через datagen_train.filenames.</p>

# %%
# https://practicum.yandex.ru/learn/data-scientist-plus/courses/1770e0c9-1225-4554-b336-96c1fc166bc0/sprints/6563/topics/a8313445-b2d5-40a1-8c78-4cf33bcbb227/lessons/b827be1d-cd01-4461-8f9c-ff12e7f36545/
width_img = height_img = 32
datagen = ImageDataGenerator() 

datagen_train = datagen.flow_from_directory(
    # папка, в которой хранится датасет
    'source',
    # папка из которой берем картики и присваиваем ей класс
    classes=['train_images'],
    # к какому размеру приводить изображения
    target_size=(width_img, height_img), 
    # размер батча
    batch_size=32,
    # в каком виде выдавать метки классов
    class_mode=None,
    # фиксируем генератор случайных чисел (от англ. random seed)
    seed=12345,
    shuffle=False)

datagen_test = datagen.flow_from_directory(
    # папка, в которой хранится датасет
    'source',
    # папка из которой берем картики и присваиваем ей класс
    classes=['test_images'],
    # к какому размеру приводить изображения
    target_size=(width_img, height_img), 
    # размер батча
    batch_size=32,
    # в каком виде выдавать метки классов
    class_mode=None,
    # фиксируем генератор случайных чисел (от англ. random seed)
    seed=12345,
    shuffle=False)
# Посомтрим какие классы у нас есть в датаген
#datagen_train.class_indices
file_names_train = [f.split('/')[-1] for f in datagen_train.filenames]
file_names_test = [f.split('/')[-1] for f in datagen_test.filenames]

def get_vec_img(mod, features_gen, features_name):
    counter_samples = 0
    count_samle = features_gen.samples
    result = dict()
    while counter_samples < count_samle:
        bat = next(features_gen)
        for item in bat:
            fn = features_name[counter_samples]
            ft = item.reshape(1, width_img, height_img, 3)
            # Буду отправлять по одному т.к. только так имена и вектора совпадают
            # При отправке пачкой результатов.
            # Ясно, что весь смысл загрузчика теряется, но я его использовать и не думал=)))
            result[fn] = mod(ft, training=False).numpy()[0].tolist() # Списки хранить удобнее в Pandas ячеках
            counter_samples = counter_samples+1 # На M1 работает чуть ли не в 2 раза быстрее чеи += 1
            print(f'{round(100 * counter_samples / count_samle)}%', end='\r', flush=True)
    print('end 100%')
    return result


model_2 = create_model_2((width_img, height_img, 3))

img_vec_3 = get_vec_img(model_2, datagen_train, file_names_train)
img_vec_4 = get_vec_img(model_2, datagen_test, file_names_test)
# Out:
# Found 1000 images belonging to 1 classes.
# Found 100 images belonging to 1 classes.
# 2022-09-16 21:17:40.237652: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# end 100%
# end 100%

# %%
#img_vec_4 = copy.deepcopy(img_vec_4_dc)
#img_vec_3 = copy.deepcopy(img_vec_3_dc)

len_v4 = []
len_v3 = []
for key, value in img_vec_4.items():
    len_v4.append(len(value))
    a = key 
    
for key, value in img_vec_3.items():
    len_v3.append(len(value))
    a = key 
print(min(len_v4)-max(len_v4))
print(min(len_v3)-max(len_v3))
# Out:
# 0
# 0

# %%
#import copy
#img_vec_4_dc = copy.deepcopy(img_vec_4)
#img_vec_3_dc = copy.deepcopy(img_vec_3)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера v2: </b></font> ❌\
# <font color='red'>Не совсем так, батч позволяет побить данные, чтобы все влезло в память, у тебя он выбран слишком большим\
# С помощью next ты получаешь только первый батч ( может, в этом причина такого большого батча?)\
#     Чтобы выполнить верно, сделаем константу BATCH_SIZE, например, 10. Зададим везде параметр batch_size=BATCH_SIZE\
#     Затем можем написать ф-цию для получения предсказаний. Я написал пример для тебя:
# ```python
# def get_predictions(keras_model, datagen):
#     batches = 0
#     for features_batch in datagen:
#         if batches == 0:
#           keras_vec_batch = keras_model(features_batch, training=False).numpy()
#         else:
#           keras_vec_batch = np.vstack((keras_vec_batch, keras_model(features_batch, training=False).numpy()))
#         batches += 1
#         print(batches, keras_vec_batch.shape)
#         if batches >= datagen.samples / BATCH_SIZE:
#                 # Сам цикл не остановится, поэтому прервем
#                 # https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
#                 break
#     return keras_vec_batch
# ```
#
# <div class="alert alert-block alert-info"><b>PIL V2:</b>
# <p>Мне кажется PIL был значительно короче в плане написания кода и практичнее в плане использования</p>
# <p>Решение с загрузчиком не выглядит как то чем имеет смысл воспользоваться =))))</p>
# <p>Теперь у меня аналог PIL только с использованием Keras 🤣</p>
# </div>

# %%
#Переехало к генераторам
#keras_vec_train = model_2(features_train, training=False).numpy()
#keras_vec_test = model_2(features_test, training=False).numpy()

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера v2: </b></font> ❌\
# <font color='red'>Здесь мы можем воспользоваться готовой моделью, обучать не нужно. Добавь, пожалуйста, параметр ```training=False```. Пример выше
#
# <div class="alert alert-block alert-info"><b>Исправил V2:</b>
# <p>Добавил к генераторам</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Возможно ошибка V1:</b>
# <p>Вот не факт что я через zip верно связал вектора и имена файлов возможно есть более верный метод</p>
# </div>

# %%
#Переехало к генераторам
#img_vec_3 = dict(zip(file_names_train,keras_vec_train))
#img_vec_4 = dict(zip(file_names_test,keras_vec_test))

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'>Тебе нужно добавить shuffle=False в datagen.flow_from_directory\
#     https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
# <div class="alert alert-block alert-info"><b>Исправил V2:</b>
# <p>Добавил к генераторам</p>
# </div>

# %% [markdown]
# ## 4. Векторизация текстов
#
# Следующий этап — векторизация текстов. Вы можете поэкспериментировать с несколькими способами векторизации текстов:
#
# - tf-idf
# - word2vec
# - \*трансформеры (например Bert)
#
# \* — если вы изучали трансформеры в спринте Машинное обучение для текстов.

# %%
df_clean = df_t[df_t['lemm']!='16+'][['image', 'query_id', 'query_clean_lemm']].copy()
#features_train_tfidf = tf_vect.fit_transform(df_clean['query_clean_lemm'])

# %%
word2vec = Word2Vec(df_clean['query_clean_lemm'].str.split(' '), min_count=1, vector_size=vector_len_for_img_and_text)
def row_to_vec(words):
    result = word2vec.wv[words.split(' ')].mean(axis=0).tolist()
    return result
features_train_word2vec = df_clean['query_clean_lemm'].apply(row_to_vec)

# %%
len_list = []

for i in features_train_word2vec:
    len_list.append(len(i))

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Хорошо

# %% [markdown]
# ## 5. Объединение векторов
#
# Подготовьте данные для обучения: объедините векторы изображений и векторы текстов с целевой переменной.

# %%
df_clean['vec_img'] = df_clean['image'].map(img_vec_3)
df_clean['word2vec'] = features_train_word2vec
df_clean.reset_index(inplace=True, drop=True)
df_clean2 = df_clean.copy()
#df_clean['tf_idf'] = pd.Series(features_train_tfidf.toarray().tolist())

# %%
# Ну будем думать, что угадал, но задача странная на объеденение векторов или я что-то не так понял
df_union = pd.merge(df_m[['image', 'query_id', 'scaler_em_a', 'scaler_em_x', 'scaler_em_y']], 
                    df_clean[['image', 'query_id', 'vec_img', 'word2vec']], 
                    how='inner', on=['image','query_id'])
df_union.dropna(inplace=True)
# Не угадал :)))))))))))
def extend_2_col(row, col1, col2):
    result = row[col1] + row[col2]
    return result
df_union['all_vec'] = df_union.apply(extend_2_col, **{'col1':'vec_img','col2':'word2vec', 'axis':1})

# %%
df = df_union[['query_id', 'image', 'scaler_em_a', 'scaler_em_x', 'scaler_em_y', 'vec_img', 'word2vec', 'all_vec']].copy()
df.reset_index(inplace=True, drop=True)
df.dropna(inplace=True)

# %%
len_w2v = []
for i in df['vec_img']:
    len_w2v.append(len(i))
print(min(len_w2v)-max(len_w2v))
len_vimg = []
for i in df['all_vec']:
    len_vimg.append(len(i))
print(min(len_vimg)-max(len_vimg))
# Out:
# 0
# 0

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>А почему угадайка? Все верно, есть два df - один с векторами, другой с оценкой, делаешь merge inner по image и query_id

# %% [markdown]
# ## 6. Обучение модели предсказания соответствия
#
# Для обучения разделите датасет на тренировочную и тестовую выборки. Простое случайное разбиение не подходит: нужно исключить попадание изображения и в обучающую, и в тестовую выборки.
# Для того чтобы учесть изображения при разбиении, можно воспользоваться классом [GroupShuffleSplit](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GroupShuffleSplit.html) из библиотеки sklearn.model_selection.
#
# Код ниже разбивает датасет на тренировочную и тестовую выборки в пропорции 7:3 так, что строки с одинаковым значением 'group_column' будут содержаться либо в тестовом, либо в тренировочном датасете.
#
# ```
# from sklearn.model_selection import GroupShuffleSplit
# gss = GroupShuffleSplit(n_splits=1, train_size=.7, random_state=42)
# train_indices, test_indices = next(gss.split(X=df.drop(columns=['target']), y=df['target'], groups=df['group_column']))
# train_df, test_df = df.loc[train_indices], df.loc[test_indices]
#
# ```
#
# Какую модель использовать — выберите самостоятельно. Также вам предстоит выбрать метрику качества либо реализовать свою.

# %%
from sklearn.model_selection import GroupShuffleSplit
gss = GroupShuffleSplit(n_splits=1, train_size=.7, random_state=42)
train_indices, test_indices = next(gss.split(X=df.drop(columns=['scaler_em_x']), 
                                             y=df['scaler_em_x'], 
                                             groups=df['image']))
train_df, test_df = df.loc[train_indices], df.loc[test_indices]

#min_vector_len_for_resize = min(train_df['vec_img'][0].shape[0], train_df['word2vec'][0].shape[0])
#y_train = np.array(train_df['vec_img'].to_list())
#x_train = np.array(train_df['word2vec'].to_list())

#y_test = np.array(test_df['vec_img'].to_list())
#x_test = np.array(test_df['word2vec'].to_list())

y_train = np.array(train_df['scaler_em_a'])
x_train = np.array(train_df['all_vec'].to_list())

y_test = np.array(test_df['scaler_em_a'])
x_test = np.array(test_df['all_vec'].to_list())

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера v2: </b></font> ❌\
# <font color='red'>Тут есть альтернативное решение. У тебя таргет при делении - это оценка, а затем картинка. И можно ведь предсказать именно оценку\
# Сделай y_train и y_test scaler_em_a, a x_train и x_test - vec_img и word2vec (можно попробовать либо раздельно их сделать, либо один столбец, объединив вектора с помощью np.hstack)\
# Так задача упростится, мы сможем предсказывать оценку соответствия, а не вектор. Заметь, что тогда сменится и метрика.\
# Логика работы функции в шаге 7 станет такой:
# * На вход приходит текст
# * Производится векторизация
# * Фичами становятся вектора изображений и этот 1 входной текст (для всех изображений)
# * Предсказывается оценка
# * Выбирается тот случай, где предсказанная оценка лучшая
# * На экран выводится входной текст и изображение, которое в паре с текстом входным, показало лучшую оценку

# %% [markdown]
# ### Это неправильная модель она делает не правильные предсказания
# Правильная модель перед картинками

# %%
early_stopping = EarlyStopping(
    monitor='root_mean_squared_error', 
    patience=10, 
    min_delta=0.001,
    mode='min'
)
STEPS_PER_EPOCH = 1
lr_schedule = InverseTimeDecay(
  1e-7,
  decay_steps=STEPS_PER_EPOCH*10000,
  decay_rate=1,
  staircase=False)
#
def create_model_for_predict_vector_3(input_len, output_len):
    m=Sequential()
    m.add(Dense(units=input_len//2*3,input_dim=input_len, activation='relu'))
    #m.add(Dense(input_len//3, activation='sigmoid'))
    m.add(Dropout(.99))
    #m.add(Dense(input_len//2, activation='sigmoid'))
    #
    m.add(Dense(output_len, activation='sigmoid'))
    m.compile(optimizer=Adam(learning_rate=lr_schedule),loss=MeanSquaredError(), metrics=RootMeanSquaredError())
    return m
x_len = x_train[0].shape[0]
y_len = 1

model3 = create_model_for_predict_vector_3(x_len, y_len)
model3.fit(x_train, y_train, validation_data=(x_test,y_test), batch_size=1, epochs=1)
# Out:
# 1191/1191 [==============================] - 27s 22ms/step - loss: 0.3624 - root_mean_squared_error: 0.6020 - val_loss: 0.2510 - val_root_mean_squared_error: 0.5010

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Предсказал как умею V2:</b>
# <p>Ну вот, что вышло))</p>
# </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера v3: </b></font> ✔️\
# <font color='green'>Модель не учится. Что можно сделать?\
#     В первую очередь давай начнем с того, что лосс стоит взять для регрессии. Например, ```loss=MeanSquaredError()```(https://keras.io/api/losses/)\
#     У нас оценка, которую хотим предсказывать, от 0 до 1, значит, нам на слое выхода relu не подходит (от 0 до бесконечности). Возьмем ```m.add(Dense(output_len, activation='sigmoid'))``` (сигмоида от 0 до 1)\
#     Увеличим количество нейронов и слоев\
#     Усложним оптимизатор, укажем learning_rate, можем добавить scheduler на learning rate для изменения скорости обучения\
#     Увеличим кол-во эпох\
# Я пообучал ночью модели и получил бейзлайн (модель все равно простая, качество не супер, и это ок, картинки предсказываются разные, этого достаточно для зачета проекта)\
# Получился такой вариант, scheduler взял по ссылке, для удобства просмотра добавил подсчет метрики rmse (их нужно импортировать из tensorflow).
# ```
# from tensorflow.keras.losses import MeanSquaredError
# from tensorflow.keras.metrics import RootMeanSquaredError
# from tensorflow.keras.optimizers.schedules import InverseTimeDecay
# ```
# Результаты были такие https://disk.yandex.ru/i/faLXEZqniRSvbg https://disk.yandex.ru/i/Xufbmmv3NLFNUQ
# ```python
# # https://tensorflow.google.cn/tutorials/keras/overfit_and_underfit
# lr_schedule = InverseTimeDecay(
#   1e-7,
#   decay_steps=STEPS_PER_EPOCH*1000,
#   decay_rate=1,
#   staircase=False)
# #
# def create_model_for_predict_vector_3(input_len, output_len):
#     m=Sequential()
#     m.add(Dense(units=input_len//3*2,input_dim=input_len, activation='relu'))
#     m.add(Dense(input_len//3, activation='relu'))
#     m.add(Dense(input_len//6, activation='relu'))
#     m.add(Dense(input_len//6, activation='relu'))
#     m.add(Dropout(.8))
#     m.add(Dense(input_len//6, activation='relu'))
#     m.add(Dense(output_len, activation='sigmoid'))
#     m.compile(optimizer=Adam(learning_rate=lr_schedule),loss=MeanSquaredError(), metrics=RootMeanSquaredError())
#     return m
# ```
#
# Сделай, пожалуйста, чтобы модель обучалась и на тестовом прогоне в 7 этапе отображались разные картинки

# %% [markdown]
# ## 7. Тестирование модели
#
# Настало время протестировать модель. Для этого получите эмбеддинги для всех тестовых изображений из папки `test_images`, выберите случайные 10 запросов из файла `test_queries.csv` и для каждого запроса выведите наиболее релевантное изображение. Сравните визуально качество поиска.

# %%
# Если в словаре нет слова то меняем его на нулевой вектор)
def row_to_vec_2(words):
    result = np.array([np.zeros(vector_len_for_img_and_text)])
    for word in words.split(' '):
        if word in word2vec.wv:
            result = np.append(result, [word2vec.wv.get_vector(word)], axis = 0)
        else:
            result = np.append(result,[np.zeros(vector_len_for_img_and_text)], axis = 0)
    result = result[1:].mean(axis=0).tolist()
    return result

# %%
df_tt = pd.read_csv('source/test_queries.csv', sep='|')
df_tt.drop('Unnamed: 0', axis=1, inplace=True)

df_tt['lemm'] = df_tt['query_text'].apply(get_lemm_word, **{'stop_words':english_stopwords,
                                                         'stop_words_my':my_stop})

df_tt['query_clean'] = df_tt['query_text'].str.replace(r'[^\w\s]', '').str.lower()

df_tt['query_clean_lemm'] = df_tt['query_clean'].apply(lemmer, **{'stop_words':english_stopwords})
df_tt['query_clean_lemm'] = df_tt['query_clean'].apply(lemmer, **{'stop_words':english_stopwords})
features_train_word2vec = df_tt['query_clean_lemm'].apply(row_to_vec_2)
df_tt['word2vec'] = features_train_word2vec

df_tt = df_tt[df_tt['lemm']!='16+'].copy()
df_tt['vec_img'] = df_tt['image'].map(img_vec_4)
# Out:
# /var/folders/5m/zj2yj9bd5m55jbrzd0_nfd6m0000gn/T/ipykernel_8139/2325505750.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_tt['query_clean'] = df_tt['query_text'].str.replace(r'[^\w\s]', '').str.lower()

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='orange'>Можно преобразования обернуть в функцию

# %%
list_for_test = list(df_tt.sample(10).index)
id_str_for_test = list_for_test[0]

def extend_2_col_2(row, col1, my_img):
    result = row[col1] + my_img 
    return result

def predict_ocenka(data, id_pred, mod=model3):
    data['ocenka'] = 0
    data['all_vec'] = 1
    query = data['word2vec'][id_pred]
    data['all_vec'] = data.apply(extend_2_col_2, **{'col1':'vec_img',
                                                    'my_img':query,
                                                    'axis':1
                                                   })
    
    x_to_pred = np.array(data['all_vec'].to_list())
    predict_img = mod.predict(x_to_pred)
    data['ocenka'] = predict_img
    razmah = data['ocenka'].max() - data['ocenka'].min()
    
    top_row = data.sort_values('ocenka', ascending=False)[['image', 'ocenka']][:1].values[0]
    name = top_row[0] # Предсказанная картинка
    ocenka = top_row[1] # Предсказанная оценка
    
    orig_ocenka = data['ocenka'][id_pred]
    display(f'{razmah:.25f}')
    return name, ocenka, orig_ocenka

# %% [markdown]
# __Описание выбора метрики:__
# В качестве метрики использую самое короткое расстояние между вектором реальной картинки и вектором предсказанной картинки мне кажется, что я так получу максимально близкий результат.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'>Хорошо, метрика выбрана. Добавь, пожалуйста, обоснование её выбора. Почему ты выбрал именно такой подход?\
#     Не очень понятно, в чем задумка предсказанного запроса. Сделай описание предполагаемого алгоритма

# %%
early_stopping = EarlyStopping(
    monitor='root_mean_squared_error', 
    patience=10, 
    min_delta=0.001,
    mode='min'
)

STEPS_PER_EPOCH = 10
lr_schedule = InverseTimeDecay(
  1e-7,
  decay_steps=STEPS_PER_EPOCH*10000,
  decay_rate=1,
  staircase=False)
#
def create_model_for_predict_vector_3(input_len, output_len):
    m=Sequential()
    m.add(Dense(units=input_len-100,input_dim=input_len, activation='relu'))
    m.add(Dense(input_len-200, activation='sigmoid'))
    m.add(Dense(input_len-300, activation='sigmoid'))
    m.add(Dense(input_len-400, activation='sigmoid'))
    m.add(Dense(input_len-500, activation='sigmoid'))
    m.add(Dense(input_len-600, activation='sigmoid'))
    m.add(Dense(input_len-700, activation='sigmoid'))
    m.add(Dense(input_len-800, activation='sigmoid'))
    m.add(Dense(input_len-900, activation='sigmoid'))
    m.add(Dense(input_len-1000, activation='sigmoid'))
    m.add(Dense(input_len//2, activation='sigmoid'))
    m.add(Dense(input_len-1400, activation='sigmoid'))
    m.add(Dense(input_len-1500, activation='sigmoid'))
    m.add(Dense(input_len-1600, activation='sigmoid'))
    m.add(Dense(input_len-1700, activation='sigmoid'))
    m.add(Dense(input_len-1800, activation='sigmoid'))
    m.add(Dense(input_len-1900, activation='sigmoid'))
    m.add(Dense(input_len-2000, activation='sigmoid'))
    #m.add(Dropout(.5))
    m.add(Dense(input_len-2020, activation='relu'))
    m.add(Dense(input_len-2010, activation='relu'))
    #
    m.add(Dense(output_len, activation='sigmoid'))
    m.compile(optimizer=Adam(learning_rate=lr_schedule), loss='mean_squared_error', metrics=RootMeanSquaredError())
    return m
x_len = x_train[0].shape[0]
y_len = 1

model3 = create_model_for_predict_vector_3(x_len, y_len)
model3.fit(x_train, y_train, validation_data=(x_test,y_test), batch_size=100, epochs=300)

list_for_test = list(df_tt.sample(10).index)
id_str_for_test = list_for_test[0]
# Out:
# Epoch 1/300
# 12/12 [==============================] - 3s 200ms/step - loss: 0.1281 - root_mean_squared_error: 0.3579 - val_loss: 0.1225 - val_root_mean_squared_error: 0.3500
# Epoch 2/300
# 12/12 [==============================] - 2s 191ms/step - loss: 0.1279 - root_mean_squared_error: 0.3576 - val_loss: 0.1222 - val_root_mean_squared_error: 0.3496
# Epoch 3/300
# 12/12 [==============================] - 2s 191ms/step - loss: 0.1276 - root_mean_squared_error: 0.3573 - val_loss: 0.1219 - val_root_mean_squared_error: 0.3492
# Epoch 4/300
# 12/12 [==============================] - 2s 194ms/step - loss: 0.1274 - root_mean_squared_error: 0.3569 - val_loss: 0.1217 - val_root_mean_squared_error: 0.3488
# Epoch 5/300
# 12/12 [==============================] - 2s 196ms/step - loss: 0.1272 - root_mean_squared_error: 0.3566 - val_loss: 0.1214 - val_root_mean_squared_error: 0.3484
# Epoch 6/300
# 12/12 [==============================] - 2s 193ms/step - loss: 0.1269 - root_mean_squared_error: 0.3563 - val_loss: 0.1211 - val_root_mean_squared_error: 0.3480
# Epoch 7/300
# 12/12 [==============================] - 2s 195ms/step - loss: 0.1267 - root_mean_squared_error: 0.3560 - val_loss: 0.1208 - val_root_mean_squared_error: 0.3476
# Epoch 8/300
# 12/12 [==============================] - 2s 195ms/step - loss: 0.1265 - root_mean_squared_error: 0.3556 - val_loss: 0.1205 - val_root_mean_squared_error: 0.3472
# Epoch 9/300
# 12/12 [==============================] - 2s 197ms/step - loss: 0.1263 - root_mean_squared_error: 0.3553 - val_loss: 0.1203 - val_root_mean_squared_error: 0.3468
# Epoch 10/300
# 12/12 [==============================] - 2s 198ms/step - loss: 0.1260 - root_mean_squared_error: 0.3550 - val_loss: 0.1200 - val_root_mean_squared_error: 0.3464
# Epoch 11/300
# 12/12 [==============================] - 2s 199ms/step - loss: 0.1258 - root_mean_squared_error: 0.3547 - val_loss: 0.1197 - val_root_mean_squared_error: 0.3460
# Epoch 12/300
# 12/12 [==============================] - 2s 202ms/step - loss: 0.1256 - root_mean_squared_error: 0.3544 - val_loss: 0.1195 - val_root_mean_squared_error: 0.3456
# Epoch 13/300
# 12/12 [==============================] - 2s 203ms/step - loss: 0.1254 - root_mean_squared_error: 0.3541 - val_loss: 0.1192 - val_root_mean_squared_error: 0.3453
# Epoch 14/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1252 - root_mean_squared_error: 0.3538 - val_loss: 0.1189 - val_root_mean_squared_error: 0.3449
# Epoch 15/300
# 12/12 [==============================] - 2s 201ms/step - loss: 0.1249 - root_mean_squared_error: 0.3535 - val_loss: 0.1187 - val_root_mean_squared_error: 0.3445
# Epoch 16/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1247 - root_mean_squared_error: 0.3532 - val_loss: 0.1184 - val_root_mean_squared_error: 0.3441
# Epoch 17/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1245 - root_mean_squared_error: 0.3529 - val_loss: 0.1182 - val_root_mean_squared_error: 0.3438
# Epoch 18/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1243 - root_mean_squared_error: 0.3526 - val_loss: 0.1179 - val_root_mean_squared_error: 0.3434
# Epoch 19/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1241 - root_mean_squared_error: 0.3523 - val_loss: 0.1177 - val_root_mean_squared_error: 0.3430
# Epoch 20/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1239 - root_mean_squared_error: 0.3520 - val_loss: 0.1174 - val_root_mean_squared_error: 0.3427
# Epoch 21/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1237 - root_mean_squared_error: 0.3517 - val_loss: 0.1172 - val_root_mean_squared_error: 0.3423
# Epoch 22/300
# 12/12 [==============================] - 3s 211ms/step - loss: 0.1235 - root_mean_squared_error: 0.3514 - val_loss: 0.1169 - val_root_mean_squared_error: 0.3420
# Epoch 23/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1233 - root_mean_squared_error: 0.3512 - val_loss: 0.1167 - val_root_mean_squared_error: 0.3416
# Epoch 24/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1231 - root_mean_squared_error: 0.3509 - val_loss: 0.1165 - val_root_mean_squared_error: 0.3413
# Epoch 25/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1229 - root_mean_squared_error: 0.3506 - val_loss: 0.1162 - val_root_mean_squared_error: 0.3409
# Epoch 26/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1227 - root_mean_squared_error: 0.3503 - val_loss: 0.1160 - val_root_mean_squared_error: 0.3406
# Epoch 27/300
# 12/12 [==============================] - 2s 202ms/step - loss: 0.1225 - root_mean_squared_error: 0.3501 - val_loss: 0.1158 - val_root_mean_squared_error: 0.3402
# Epoch 28/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1224 - root_mean_squared_error: 0.3498 - val_loss: 0.1155 - val_root_mean_squared_error: 0.3399
# Epoch 29/300
# 12/12 [==============================] - 2s 202ms/step - loss: 0.1222 - root_mean_squared_error: 0.3495 - val_loss: 0.1153 - val_root_mean_squared_error: 0.3396
# Epoch 30/300
# 12/12 [==============================] - 2s 199ms/step - loss: 0.1220 - root_mean_squared_error: 0.3493 - val_loss: 0.1151 - val_root_mean_squared_error: 0.3392
# Epoch 31/300
# 12/12 [==============================] - 2s 200ms/step - loss: 0.1218 - root_mean_squared_error: 0.3490 - val_loss: 0.1149 - val_root_mean_squared_error: 0.3389
# Epoch 32/300
# 12/12 [==============================] - 2s 203ms/step - loss: 0.1216 - root_mean_squared_error: 0.3488 - val_loss: 0.1146 - val_root_mean_squared_error: 0.3386
# Epoch 33/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1215 - root_mean_squared_error: 0.3485 - val_loss: 0.1144 - val_root_mean_squared_error: 0.3383
# Epoch 34/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1213 - root_mean_squared_error: 0.3483 - val_loss: 0.1142 - val_root_mean_squared_error: 0.3379
# Epoch 35/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1211 - root_mean_squared_error: 0.3480 - val_loss: 0.1140 - val_root_mean_squared_error: 0.3376
# Epoch 36/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1210 - root_mean_squared_error: 0.3478 - val_loss: 0.1138 - val_root_mean_squared_error: 0.3373
# Epoch 37/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1208 - root_mean_squared_error: 0.3475 - val_loss: 0.1136 - val_root_mean_squared_error: 0.3370
# Epoch 38/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1206 - root_mean_squared_error: 0.3473 - val_loss: 0.1134 - val_root_mean_squared_error: 0.3367
# Epoch 39/300
# 12/12 [==============================] - 3s 227ms/step - loss: 0.1205 - root_mean_squared_error: 0.3471 - val_loss: 0.1132 - val_root_mean_squared_error: 0.3364
# Epoch 40/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1203 - root_mean_squared_error: 0.3468 - val_loss: 0.1130 - val_root_mean_squared_error: 0.3361
# Epoch 41/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1201 - root_mean_squared_error: 0.3466 - val_loss: 0.1128 - val_root_mean_squared_error: 0.3358
# Epoch 42/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1200 - root_mean_squared_error: 0.3464 - val_loss: 0.1126 - val_root_mean_squared_error: 0.3355
# Epoch 43/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1198 - root_mean_squared_error: 0.3462 - val_loss: 0.1124 - val_root_mean_squared_error: 0.3352
# Epoch 44/300
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1197 - root_mean_squared_error: 0.3459 - val_loss: 0.1122 - val_root_mean_squared_error: 0.3349
# Epoch 45/300
# 12/12 [==============================] - 3s 228ms/step - loss: 0.1195 - root_mean_squared_error: 0.3457 - val_loss: 0.1120 - val_root_mean_squared_error: 0.3346
# Epoch 46/300
# 12/12 [==============================] - 3s 226ms/step - loss: 0.1194 - root_mean_squared_error: 0.3455 - val_loss: 0.1118 - val_root_mean_squared_error: 0.3344
# Epoch 47/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1192 - root_mean_squared_error: 0.3453 - val_loss: 0.1116 - val_root_mean_squared_error: 0.3341
# Epoch 48/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1191 - root_mean_squared_error: 0.3451 - val_loss: 0.1114 - val_root_mean_squared_error: 0.3338
# Epoch 49/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1189 - root_mean_squared_error: 0.3449 - val_loss: 0.1112 - val_root_mean_squared_error: 0.3335
# Epoch 50/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1188 - root_mean_squared_error: 0.3447 - val_loss: 0.1111 - val_root_mean_squared_error: 0.3333
# Epoch 51/300
# 12/12 [==============================] - 3s 238ms/step - loss: 0.1186 - root_mean_squared_error: 0.3445 - val_loss: 0.1109 - val_root_mean_squared_error: 0.3330
# Epoch 52/300
# 12/12 [==============================] - 3s 231ms/step - loss: 0.1185 - root_mean_squared_error: 0.3442 - val_loss: 0.1107 - val_root_mean_squared_error: 0.3327
# Epoch 53/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1184 - root_mean_squared_error: 0.3441 - val_loss: 0.1105 - val_root_mean_squared_error: 0.3324
# Epoch 54/300
# 12/12 [==============================] - 3s 239ms/step - loss: 0.1182 - root_mean_squared_error: 0.3438 - val_loss: 0.1103 - val_root_mean_squared_error: 0.3322
# Epoch 55/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1181 - root_mean_squared_error: 0.3437 - val_loss: 0.1102 - val_root_mean_squared_error: 0.3319
# Epoch 56/300
# 12/12 [==============================] - 3s 225ms/step - loss: 0.1180 - root_mean_squared_error: 0.3435 - val_loss: 0.1100 - val_root_mean_squared_error: 0.3317
# Epoch 57/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1178 - root_mean_squared_error: 0.3433 - val_loss: 0.1098 - val_root_mean_squared_error: 0.3314
# Epoch 58/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1177 - root_mean_squared_error: 0.3431 - val_loss: 0.1097 - val_root_mean_squared_error: 0.3311
# Epoch 59/300
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1176 - root_mean_squared_error: 0.3429 - val_loss: 0.1095 - val_root_mean_squared_error: 0.3309
# Epoch 60/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1174 - root_mean_squared_error: 0.3427 - val_loss: 0.1093 - val_root_mean_squared_error: 0.3306
# Epoch 61/300
# 12/12 [==============================] - 3s 238ms/step - loss: 0.1173 - root_mean_squared_error: 0.3425 - val_loss: 0.1092 - val_root_mean_squared_error: 0.3304
# Epoch 62/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1172 - root_mean_squared_error: 0.3423 - val_loss: 0.1090 - val_root_mean_squared_error: 0.3301
# Epoch 63/300
# 12/12 [==============================] - 3s 227ms/step - loss: 0.1170 - root_mean_squared_error: 0.3421 - val_loss: 0.1088 - val_root_mean_squared_error: 0.3299
# Epoch 64/300
# 12/12 [==============================] - 3s 224ms/step - loss: 0.1169 - root_mean_squared_error: 0.3419 - val_loss: 0.1087 - val_root_mean_squared_error: 0.3296
# Epoch 65/300
# 12/12 [==============================] - 3s 229ms/step - loss: 0.1168 - root_mean_squared_error: 0.3418 - val_loss: 0.1085 - val_root_mean_squared_error: 0.3294
# Epoch 66/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1167 - root_mean_squared_error: 0.3416 - val_loss: 0.1083 - val_root_mean_squared_error: 0.3292
# Epoch 67/300
# 12/12 [==============================] - 3s 234ms/step - loss: 0.1166 - root_mean_squared_error: 0.3414 - val_loss: 0.1082 - val_root_mean_squared_error: 0.3289
# Epoch 68/300
# 12/12 [==============================] - 3s 224ms/step - loss: 0.1164 - root_mean_squared_error: 0.3412 - val_loss: 0.1080 - val_root_mean_squared_error: 0.3287
# Epoch 69/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1163 - root_mean_squared_error: 0.3411 - val_loss: 0.1079 - val_root_mean_squared_error: 0.3284
# Epoch 70/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1162 - root_mean_squared_error: 0.3409 - val_loss: 0.1077 - val_root_mean_squared_error: 0.3282
# Epoch 71/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1161 - root_mean_squared_error: 0.3407 - val_loss: 0.1076 - val_root_mean_squared_error: 0.3280
# Epoch 72/300
# 12/12 [==============================] - 3s 229ms/step - loss: 0.1160 - root_mean_squared_error: 0.3405 - val_loss: 0.1074 - val_root_mean_squared_error: 0.3277
# Epoch 73/300
# 12/12 [==============================] - 3s 226ms/step - loss: 0.1159 - root_mean_squared_error: 0.3404 - val_loss: 0.1073 - val_root_mean_squared_error: 0.3275
# Epoch 74/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1157 - root_mean_squared_error: 0.3402 - val_loss: 0.1071 - val_root_mean_squared_error: 0.3273
# Epoch 75/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1156 - root_mean_squared_error: 0.3401 - val_loss: 0.1070 - val_root_mean_squared_error: 0.3271
# Epoch 76/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1155 - root_mean_squared_error: 0.3399 - val_loss: 0.1068 - val_root_mean_squared_error: 0.3269
# Epoch 77/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1154 - root_mean_squared_error: 0.3397 - val_loss: 0.1067 - val_root_mean_squared_error: 0.3266
# Epoch 78/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1153 - root_mean_squared_error: 0.3396 - val_loss: 0.1065 - val_root_mean_squared_error: 0.3264
# Epoch 79/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1152 - root_mean_squared_error: 0.3394 - val_loss: 0.1064 - val_root_mean_squared_error: 0.3262
# Epoch 80/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1151 - root_mean_squared_error: 0.3393 - val_loss: 0.1063 - val_root_mean_squared_error: 0.3260
# Epoch 81/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1150 - root_mean_squared_error: 0.3391 - val_loss: 0.1061 - val_root_mean_squared_error: 0.3258
# Epoch 82/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1149 - root_mean_squared_error: 0.3390 - val_loss: 0.1060 - val_root_mean_squared_error: 0.3256
# Epoch 83/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1148 - root_mean_squared_error: 0.3388 - val_loss: 0.1059 - val_root_mean_squared_error: 0.3254
# Epoch 84/300
# 12/12 [==============================] - 3s 211ms/step - loss: 0.1147 - root_mean_squared_error: 0.3387 - val_loss: 0.1057 - val_root_mean_squared_error: 0.3252
# Epoch 85/300
# 12/12 [==============================] - 3s 211ms/step - loss: 0.1146 - root_mean_squared_error: 0.3385 - val_loss: 0.1056 - val_root_mean_squared_error: 0.3249
# Epoch 86/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1145 - root_mean_squared_error: 0.3384 - val_loss: 0.1055 - val_root_mean_squared_error: 0.3247
# Epoch 87/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1144 - root_mean_squared_error: 0.3382 - val_loss: 0.1053 - val_root_mean_squared_error: 0.3245
# Epoch 88/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1143 - root_mean_squared_error: 0.3381 - val_loss: 0.1052 - val_root_mean_squared_error: 0.3243
# Epoch 89/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1142 - root_mean_squared_error: 0.3379 - val_loss: 0.1051 - val_root_mean_squared_error: 0.3241
# Epoch 90/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1141 - root_mean_squared_error: 0.3378 - val_loss: 0.1049 - val_root_mean_squared_error: 0.3239
# Epoch 91/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1140 - root_mean_squared_error: 0.3377 - val_loss: 0.1048 - val_root_mean_squared_error: 0.3238
# Epoch 92/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1139 - root_mean_squared_error: 0.3375 - val_loss: 0.1047 - val_root_mean_squared_error: 0.3236
# Epoch 93/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1138 - root_mean_squared_error: 0.3374 - val_loss: 0.1046 - val_root_mean_squared_error: 0.3234
# Epoch 94/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1137 - root_mean_squared_error: 0.3373 - val_loss: 0.1045 - val_root_mean_squared_error: 0.3232
# Epoch 95/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1137 - root_mean_squared_error: 0.3371 - val_loss: 0.1043 - val_root_mean_squared_error: 0.3230
# Epoch 96/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1136 - root_mean_squared_error: 0.3370 - val_loss: 0.1042 - val_root_mean_squared_error: 0.3228
# Epoch 97/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1135 - root_mean_squared_error: 0.3369 - val_loss: 0.1041 - val_root_mean_squared_error: 0.3226
# Epoch 98/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1134 - root_mean_squared_error: 0.3367 - val_loss: 0.1040 - val_root_mean_squared_error: 0.3224
# Epoch 99/300
# 12/12 [==============================] - 3s 224ms/step - loss: 0.1133 - root_mean_squared_error: 0.3366 - val_loss: 0.1039 - val_root_mean_squared_error: 0.3223
# Epoch 100/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1132 - root_mean_squared_error: 0.3365 - val_loss: 0.1037 - val_root_mean_squared_error: 0.3221
# Epoch 101/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1131 - root_mean_squared_error: 0.3364 - val_loss: 0.1036 - val_root_mean_squared_error: 0.3219
# Epoch 102/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1131 - root_mean_squared_error: 0.3363 - val_loss: 0.1035 - val_root_mean_squared_error: 0.3217
# Epoch 103/300
# 12/12 [==============================] - 3s 224ms/step - loss: 0.1130 - root_mean_squared_error: 0.3361 - val_loss: 0.1034 - val_root_mean_squared_error: 0.3216
# Epoch 104/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1129 - root_mean_squared_error: 0.3360 - val_loss: 0.1033 - val_root_mean_squared_error: 0.3214
# Epoch 105/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1128 - root_mean_squared_error: 0.3359 - val_loss: 0.1032 - val_root_mean_squared_error: 0.3212
# Epoch 106/300
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1128 - root_mean_squared_error: 0.3358 - val_loss: 0.1031 - val_root_mean_squared_error: 0.3211
# Epoch 107/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1127 - root_mean_squared_error: 0.3357 - val_loss: 0.1030 - val_root_mean_squared_error: 0.3209
# Epoch 108/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1126 - root_mean_squared_error: 0.3356 - val_loss: 0.1029 - val_root_mean_squared_error: 0.3207
# Epoch 109/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1125 - root_mean_squared_error: 0.3355 - val_loss: 0.1028 - val_root_mean_squared_error: 0.3206
# Epoch 110/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1125 - root_mean_squared_error: 0.3353 - val_loss: 0.1027 - val_root_mean_squared_error: 0.3204
# Epoch 111/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1124 - root_mean_squared_error: 0.3352 - val_loss: 0.1025 - val_root_mean_squared_error: 0.3202
# Epoch 112/300
# 12/12 [==============================] - 3s 227ms/step - loss: 0.1123 - root_mean_squared_error: 0.3351 - val_loss: 0.1025 - val_root_mean_squared_error: 0.3201
# Epoch 113/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1122 - root_mean_squared_error: 0.3350 - val_loss: 0.1024 - val_root_mean_squared_error: 0.3199
# Epoch 114/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1122 - root_mean_squared_error: 0.3349 - val_loss: 0.1023 - val_root_mean_squared_error: 0.3198
# Epoch 115/300
# 12/12 [==============================] - 3s 228ms/step - loss: 0.1121 - root_mean_squared_error: 0.3348 - val_loss: 0.1022 - val_root_mean_squared_error: 0.3196
# Epoch 116/300
# 12/12 [==============================] - 3s 227ms/step - loss: 0.1120 - root_mean_squared_error: 0.3347 - val_loss: 0.1021 - val_root_mean_squared_error: 0.3195
# Epoch 117/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1120 - root_mean_squared_error: 0.3346 - val_loss: 0.1020 - val_root_mean_squared_error: 0.3193
# Epoch 118/300
# 12/12 [==============================] - 3s 225ms/step - loss: 0.1119 - root_mean_squared_error: 0.3345 - val_loss: 0.1019 - val_root_mean_squared_error: 0.3192
# Epoch 119/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1118 - root_mean_squared_error: 0.3344 - val_loss: 0.1018 - val_root_mean_squared_error: 0.3190
# Epoch 120/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1118 - root_mean_squared_error: 0.3343 - val_loss: 0.1017 - val_root_mean_squared_error: 0.3189
# Epoch 121/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1117 - root_mean_squared_error: 0.3342 - val_loss: 0.1016 - val_root_mean_squared_error: 0.3187
# Epoch 122/300
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1116 - root_mean_squared_error: 0.3341 - val_loss: 0.1015 - val_root_mean_squared_error: 0.3186
# Epoch 123/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1116 - root_mean_squared_error: 0.3340 - val_loss: 0.1014 - val_root_mean_squared_error: 0.3184
# Epoch 124/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1115 - root_mean_squared_error: 0.3339 - val_loss: 0.1013 - val_root_mean_squared_error: 0.3183
# Epoch 125/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1115 - root_mean_squared_error: 0.3339 - val_loss: 0.1012 - val_root_mean_squared_error: 0.3182
# Epoch 126/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1114 - root_mean_squared_error: 0.3338 - val_loss: 0.1011 - val_root_mean_squared_error: 0.3180
# Epoch 127/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1113 - root_mean_squared_error: 0.3337 - val_loss: 0.1011 - val_root_mean_squared_error: 0.3179
# Epoch 128/300
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1113 - root_mean_squared_error: 0.3336 - val_loss: 0.1010 - val_root_mean_squared_error: 0.3177
# Epoch 129/300
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1112 - root_mean_squared_error: 0.3335 - val_loss: 0.1009 - val_root_mean_squared_error: 0.3176
# Epoch 130/300
# 12/12 [==============================] - 3s 225ms/step - loss: 0.1112 - root_mean_squared_error: 0.3334 - val_loss: 0.1008 - val_root_mean_squared_error: 0.3175
# Epoch 131/300
# 12/12 [==============================] - 3s 232ms/step - loss: 0.1111 - root_mean_squared_error: 0.3333 - val_loss: 0.1007 - val_root_mean_squared_error: 0.3173
# Epoch 132/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1110 - root_mean_squared_error: 0.3332 - val_loss: 0.1006 - val_root_mean_squared_error: 0.3172
# Epoch 133/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1110 - root_mean_squared_error: 0.3332 - val_loss: 0.1005 - val_root_mean_squared_error: 0.3171
# Epoch 134/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1109 - root_mean_squared_error: 0.3331 - val_loss: 0.1005 - val_root_mean_squared_error: 0.3170
# Epoch 135/300
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1109 - root_mean_squared_error: 0.3330 - val_loss: 0.1004 - val_root_mean_squared_error: 0.3168
# Epoch 136/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1108 - root_mean_squared_error: 0.3329 - val_loss: 0.1003 - val_root_mean_squared_error: 0.3167
# Epoch 137/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1108 - root_mean_squared_error: 0.3328 - val_loss: 0.1002 - val_root_mean_squared_error: 0.3166
# Epoch 138/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1107 - root_mean_squared_error: 0.3328 - val_loss: 0.1002 - val_root_mean_squared_error: 0.3165
# Epoch 139/300
# 12/12 [==============================] - 3s 224ms/step - loss: 0.1107 - root_mean_squared_error: 0.3327 - val_loss: 0.1001 - val_root_mean_squared_error: 0.3163
# Epoch 140/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1106 - root_mean_squared_error: 0.3326 - val_loss: 0.1000 - val_root_mean_squared_error: 0.3162
# Epoch 141/300
# 12/12 [==============================] - 3s 225ms/step - loss: 0.1106 - root_mean_squared_error: 0.3326 - val_loss: 0.0999 - val_root_mean_squared_error: 0.3161
# Epoch 142/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1105 - root_mean_squared_error: 0.3325 - val_loss: 0.0999 - val_root_mean_squared_error: 0.3160
# Epoch 143/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1105 - root_mean_squared_error: 0.3324 - val_loss: 0.0998 - val_root_mean_squared_error: 0.3159
# Epoch 144/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1104 - root_mean_squared_error: 0.3323 - val_loss: 0.0997 - val_root_mean_squared_error: 0.3158
# Epoch 145/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1104 - root_mean_squared_error: 0.3323 - val_loss: 0.0996 - val_root_mean_squared_error: 0.3157
# Epoch 146/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1104 - root_mean_squared_error: 0.3322 - val_loss: 0.0996 - val_root_mean_squared_error: 0.3155
# Epoch 147/300
# 12/12 [==============================] - 3s 211ms/step - loss: 0.1103 - root_mean_squared_error: 0.3321 - val_loss: 0.0995 - val_root_mean_squared_error: 0.3154
# Epoch 148/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1103 - root_mean_squared_error: 0.3321 - val_loss: 0.0994 - val_root_mean_squared_error: 0.3153
# Epoch 149/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1102 - root_mean_squared_error: 0.3320 - val_loss: 0.0994 - val_root_mean_squared_error: 0.3152
# Epoch 150/300
# 12/12 [==============================] - 3s 211ms/step - loss: 0.1102 - root_mean_squared_error: 0.3319 - val_loss: 0.0993 - val_root_mean_squared_error: 0.3151
# Epoch 151/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1101 - root_mean_squared_error: 0.3319 - val_loss: 0.0992 - val_root_mean_squared_error: 0.3150
# Epoch 152/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1101 - root_mean_squared_error: 0.3318 - val_loss: 0.0992 - val_root_mean_squared_error: 0.3149
# Epoch 153/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1101 - root_mean_squared_error: 0.3317 - val_loss: 0.0991 - val_root_mean_squared_error: 0.3148
# Epoch 154/300
# 12/12 [==============================] - 2s 202ms/step - loss: 0.1100 - root_mean_squared_error: 0.3317 - val_loss: 0.0990 - val_root_mean_squared_error: 0.3147
# Epoch 155/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1100 - root_mean_squared_error: 0.3316 - val_loss: 0.0990 - val_root_mean_squared_error: 0.3146
# Epoch 156/300
# 12/12 [==============================] - 2s 202ms/step - loss: 0.1099 - root_mean_squared_error: 0.3316 - val_loss: 0.0989 - val_root_mean_squared_error: 0.3145
# Epoch 157/300
# 12/12 [==============================] - 2s 202ms/step - loss: 0.1099 - root_mean_squared_error: 0.3315 - val_loss: 0.0988 - val_root_mean_squared_error: 0.3144
# Epoch 158/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1099 - root_mean_squared_error: 0.3314 - val_loss: 0.0988 - val_root_mean_squared_error: 0.3143
# Epoch 159/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1098 - root_mean_squared_error: 0.3314 - val_loss: 0.0987 - val_root_mean_squared_error: 0.3142
# Epoch 160/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1098 - root_mean_squared_error: 0.3313 - val_loss: 0.0987 - val_root_mean_squared_error: 0.3141
# Epoch 161/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1097 - root_mean_squared_error: 0.3313 - val_loss: 0.0986 - val_root_mean_squared_error: 0.3140
# Epoch 162/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1097 - root_mean_squared_error: 0.3312 - val_loss: 0.0985 - val_root_mean_squared_error: 0.3139
# Epoch 163/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1097 - root_mean_squared_error: 0.3312 - val_loss: 0.0985 - val_root_mean_squared_error: 0.3138
# Epoch 164/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1096 - root_mean_squared_error: 0.3311 - val_loss: 0.0984 - val_root_mean_squared_error: 0.3137
# Epoch 165/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1096 - root_mean_squared_error: 0.3311 - val_loss: 0.0984 - val_root_mean_squared_error: 0.3136
# Epoch 166/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1096 - root_mean_squared_error: 0.3310 - val_loss: 0.0983 - val_root_mean_squared_error: 0.3135
# Epoch 167/300
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1095 - root_mean_squared_error: 0.3309 - val_loss: 0.0982 - val_root_mean_squared_error: 0.3134
# Epoch 168/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1095 - root_mean_squared_error: 0.3309 - val_loss: 0.0982 - val_root_mean_squared_error: 0.3133
# Epoch 169/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1095 - root_mean_squared_error: 0.3308 - val_loss: 0.0981 - val_root_mean_squared_error: 0.3133
# Epoch 170/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1094 - root_mean_squared_error: 0.3308 - val_loss: 0.0981 - val_root_mean_squared_error: 0.3132
# Epoch 171/300
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1094 - root_mean_squared_error: 0.3307 - val_loss: 0.0980 - val_root_mean_squared_error: 0.3131
# Epoch 172/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1094 - root_mean_squared_error: 0.3307 - val_loss: 0.0980 - val_root_mean_squared_error: 0.3130
# Epoch 173/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1093 - root_mean_squared_error: 0.3307 - val_loss: 0.0979 - val_root_mean_squared_error: 0.3129
# Epoch 174/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1093 - root_mean_squared_error: 0.3306 - val_loss: 0.0979 - val_root_mean_squared_error: 0.3128
# Epoch 175/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1093 - root_mean_squared_error: 0.3306 - val_loss: 0.0978 - val_root_mean_squared_error: 0.3128
# Epoch 176/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1092 - root_mean_squared_error: 0.3305 - val_loss: 0.0978 - val_root_mean_squared_error: 0.3127
# Epoch 177/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1092 - root_mean_squared_error: 0.3305 - val_loss: 0.0977 - val_root_mean_squared_error: 0.3126
# Epoch 178/300
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1092 - root_mean_squared_error: 0.3304 - val_loss: 0.0977 - val_root_mean_squared_error: 0.3125
# Epoch 179/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1092 - root_mean_squared_error: 0.3304 - val_loss: 0.0976 - val_root_mean_squared_error: 0.3124
# Epoch 180/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1091 - root_mean_squared_error: 0.3303 - val_loss: 0.0976 - val_root_mean_squared_error: 0.3124
# Epoch 181/300
# 12/12 [==============================] - 3s 225ms/step - loss: 0.1091 - root_mean_squared_error: 0.3303 - val_loss: 0.0975 - val_root_mean_squared_error: 0.3123
# Epoch 182/300
# 12/12 [==============================] - 3s 230ms/step - loss: 0.1091 - root_mean_squared_error: 0.3303 - val_loss: 0.0975 - val_root_mean_squared_error: 0.3122
# Epoch 183/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1090 - root_mean_squared_error: 0.3302 - val_loss: 0.0974 - val_root_mean_squared_error: 0.3121
# Epoch 184/300
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1090 - root_mean_squared_error: 0.3302 - val_loss: 0.0974 - val_root_mean_squared_error: 0.3120
# Epoch 185/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1090 - root_mean_squared_error: 0.3301 - val_loss: 0.0973 - val_root_mean_squared_error: 0.3120
# Epoch 186/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1090 - root_mean_squared_error: 0.3301 - val_loss: 0.0973 - val_root_mean_squared_error: 0.3119
# Epoch 187/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1089 - root_mean_squared_error: 0.3301 - val_loss: 0.0972 - val_root_mean_squared_error: 0.3118
# Epoch 188/300
# 12/12 [==============================] - 2s 203ms/step - loss: 0.1089 - root_mean_squared_error: 0.3300 - val_loss: 0.0972 - val_root_mean_squared_error: 0.3117
# Epoch 189/300
# 12/12 [==============================] - 2s 202ms/step - loss: 0.1089 - root_mean_squared_error: 0.3300 - val_loss: 0.0971 - val_root_mean_squared_error: 0.3117
# Epoch 190/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1089 - root_mean_squared_error: 0.3299 - val_loss: 0.0971 - val_root_mean_squared_error: 0.3116
# Epoch 191/300
# 12/12 [==============================] - 2s 201ms/step - loss: 0.1088 - root_mean_squared_error: 0.3299 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3115
# Epoch 192/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1088 - root_mean_squared_error: 0.3299 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3115
# Epoch 193/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1088 - root_mean_squared_error: 0.3298 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3114
# Epoch 194/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1088 - root_mean_squared_error: 0.3298 - val_loss: 0.0969 - val_root_mean_squared_error: 0.3113
# Epoch 195/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1087 - root_mean_squared_error: 0.3298 - val_loss: 0.0969 - val_root_mean_squared_error: 0.3112
# Epoch 196/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1087 - root_mean_squared_error: 0.3297 - val_loss: 0.0968 - val_root_mean_squared_error: 0.3112
# Epoch 197/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1087 - root_mean_squared_error: 0.3297 - val_loss: 0.0968 - val_root_mean_squared_error: 0.3111
# Epoch 198/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1087 - root_mean_squared_error: 0.3296 - val_loss: 0.0967 - val_root_mean_squared_error: 0.3110
# Epoch 199/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1086 - root_mean_squared_error: 0.3296 - val_loss: 0.0967 - val_root_mean_squared_error: 0.3110
# Epoch 200/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1086 - root_mean_squared_error: 0.3296 - val_loss: 0.0967 - val_root_mean_squared_error: 0.3109
# Epoch 201/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1086 - root_mean_squared_error: 0.3296 - val_loss: 0.0966 - val_root_mean_squared_error: 0.3108
# Epoch 202/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1086 - root_mean_squared_error: 0.3295 - val_loss: 0.0966 - val_root_mean_squared_error: 0.3108
# Epoch 203/300
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1086 - root_mean_squared_error: 0.3295 - val_loss: 0.0965 - val_root_mean_squared_error: 0.3107
# Epoch 204/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1085 - root_mean_squared_error: 0.3295 - val_loss: 0.0965 - val_root_mean_squared_error: 0.3106
# Epoch 205/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1085 - root_mean_squared_error: 0.3294 - val_loss: 0.0965 - val_root_mean_squared_error: 0.3106
# Epoch 206/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1085 - root_mean_squared_error: 0.3294 - val_loss: 0.0964 - val_root_mean_squared_error: 0.3105
# Epoch 207/300
# 12/12 [==============================] - 3s 211ms/step - loss: 0.1085 - root_mean_squared_error: 0.3294 - val_loss: 0.0964 - val_root_mean_squared_error: 0.3105
# Epoch 208/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1085 - root_mean_squared_error: 0.3293 - val_loss: 0.0963 - val_root_mean_squared_error: 0.3104
# Epoch 209/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1084 - root_mean_squared_error: 0.3293 - val_loss: 0.0963 - val_root_mean_squared_error: 0.3103
# Epoch 210/300
# 12/12 [==============================] - 3s 225ms/step - loss: 0.1084 - root_mean_squared_error: 0.3293 - val_loss: 0.0963 - val_root_mean_squared_error: 0.3103
# Epoch 211/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1084 - root_mean_squared_error: 0.3293 - val_loss: 0.0962 - val_root_mean_squared_error: 0.3102
# Epoch 212/300
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1084 - root_mean_squared_error: 0.3292 - val_loss: 0.0962 - val_root_mean_squared_error: 0.3102
# Epoch 213/300
# 12/12 [==============================] - 3s 236ms/step - loss: 0.1084 - root_mean_squared_error: 0.3292 - val_loss: 0.0962 - val_root_mean_squared_error: 0.3101
# Epoch 214/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1084 - root_mean_squared_error: 0.3292 - val_loss: 0.0961 - val_root_mean_squared_error: 0.3101
# Epoch 215/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1083 - root_mean_squared_error: 0.3292 - val_loss: 0.0961 - val_root_mean_squared_error: 0.3100
# Epoch 216/300
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1083 - root_mean_squared_error: 0.3291 - val_loss: 0.0961 - val_root_mean_squared_error: 0.3099
# Epoch 217/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1083 - root_mean_squared_error: 0.3291 - val_loss: 0.0960 - val_root_mean_squared_error: 0.3099
# Epoch 218/300
# 12/12 [==============================] - 3s 229ms/step - loss: 0.1083 - root_mean_squared_error: 0.3291 - val_loss: 0.0960 - val_root_mean_squared_error: 0.3098
# Epoch 219/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1083 - root_mean_squared_error: 0.3291 - val_loss: 0.0960 - val_root_mean_squared_error: 0.3098
# Epoch 220/300
# 12/12 [==============================] - 3s 226ms/step - loss: 0.1083 - root_mean_squared_error: 0.3290 - val_loss: 0.0959 - val_root_mean_squared_error: 0.3097
# Epoch 221/300
# 12/12 [==============================] - 3s 232ms/step - loss: 0.1083 - root_mean_squared_error: 0.3290 - val_loss: 0.0959 - val_root_mean_squared_error: 0.3097
# Epoch 222/300
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1082 - root_mean_squared_error: 0.3290 - val_loss: 0.0959 - val_root_mean_squared_error: 0.3096
# Epoch 223/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1082 - root_mean_squared_error: 0.3290 - val_loss: 0.0958 - val_root_mean_squared_error: 0.3096
# Epoch 224/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1082 - root_mean_squared_error: 0.3289 - val_loss: 0.0958 - val_root_mean_squared_error: 0.3095
# Epoch 225/300
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1082 - root_mean_squared_error: 0.3289 - val_loss: 0.0958 - val_root_mean_squared_error: 0.3095
# Epoch 226/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1082 - root_mean_squared_error: 0.3289 - val_loss: 0.0958 - val_root_mean_squared_error: 0.3094
# Epoch 227/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1082 - root_mean_squared_error: 0.3289 - val_loss: 0.0957 - val_root_mean_squared_error: 0.3094
# Epoch 228/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1082 - root_mean_squared_error: 0.3289 - val_loss: 0.0957 - val_root_mean_squared_error: 0.3093
# Epoch 229/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1081 - root_mean_squared_error: 0.3288 - val_loss: 0.0957 - val_root_mean_squared_error: 0.3093
# Epoch 230/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1081 - root_mean_squared_error: 0.3288 - val_loss: 0.0956 - val_root_mean_squared_error: 0.3093
# Epoch 231/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1081 - root_mean_squared_error: 0.3288 - val_loss: 0.0956 - val_root_mean_squared_error: 0.3092
# Epoch 232/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1081 - root_mean_squared_error: 0.3288 - val_loss: 0.0956 - val_root_mean_squared_error: 0.3092
# Epoch 233/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1081 - root_mean_squared_error: 0.3288 - val_loss: 0.0956 - val_root_mean_squared_error: 0.3091
# Epoch 234/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1081 - root_mean_squared_error: 0.3288 - val_loss: 0.0955 - val_root_mean_squared_error: 0.3091
# Epoch 235/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1081 - root_mean_squared_error: 0.3287 - val_loss: 0.0955 - val_root_mean_squared_error: 0.3090
# Epoch 236/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1081 - root_mean_squared_error: 0.3287 - val_loss: 0.0955 - val_root_mean_squared_error: 0.3090
# Epoch 237/300
# 12/12 [==============================] - 2s 202ms/step - loss: 0.1081 - root_mean_squared_error: 0.3287 - val_loss: 0.0955 - val_root_mean_squared_error: 0.3090
# Epoch 238/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1080 - root_mean_squared_error: 0.3287 - val_loss: 0.0954 - val_root_mean_squared_error: 0.3089
# Epoch 239/300
# 12/12 [==============================] - 3s 224ms/step - loss: 0.1080 - root_mean_squared_error: 0.3287 - val_loss: 0.0954 - val_root_mean_squared_error: 0.3089
# Epoch 240/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1080 - root_mean_squared_error: 0.3287 - val_loss: 0.0954 - val_root_mean_squared_error: 0.3088
# Epoch 241/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1080 - root_mean_squared_error: 0.3287 - val_loss: 0.0954 - val_root_mean_squared_error: 0.3088
# Epoch 242/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1080 - root_mean_squared_error: 0.3286 - val_loss: 0.0953 - val_root_mean_squared_error: 0.3088
# Epoch 243/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1080 - root_mean_squared_error: 0.3286 - val_loss: 0.0953 - val_root_mean_squared_error: 0.3087
# Epoch 244/300
# 12/12 [==============================] - 3s 211ms/step - loss: 0.1080 - root_mean_squared_error: 0.3286 - val_loss: 0.0953 - val_root_mean_squared_error: 0.3087
# Epoch 245/300
# 12/12 [==============================] - 2s 210ms/step - loss: 0.1080 - root_mean_squared_error: 0.3286 - val_loss: 0.0953 - val_root_mean_squared_error: 0.3087
# Epoch 246/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1080 - root_mean_squared_error: 0.3286 - val_loss: 0.0952 - val_root_mean_squared_error: 0.3086
# Epoch 247/300
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1080 - root_mean_squared_error: 0.3286 - val_loss: 0.0952 - val_root_mean_squared_error: 0.3086
# Epoch 248/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1079 - root_mean_squared_error: 0.3286 - val_loss: 0.0952 - val_root_mean_squared_error: 0.3086
# Epoch 249/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1079 - root_mean_squared_error: 0.3285 - val_loss: 0.0952 - val_root_mean_squared_error: 0.3085
# Epoch 250/300
# 12/12 [==============================] - 2s 203ms/step - loss: 0.1079 - root_mean_squared_error: 0.3285 - val_loss: 0.0952 - val_root_mean_squared_error: 0.3085
# Epoch 251/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1079 - root_mean_squared_error: 0.3285 - val_loss: 0.0951 - val_root_mean_squared_error: 0.3084
# Epoch 252/300
# 12/12 [==============================] - 3s 210ms/step - loss: 0.1079 - root_mean_squared_error: 0.3285 - val_loss: 0.0951 - val_root_mean_squared_error: 0.3084
# Epoch 253/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1079 - root_mean_squared_error: 0.3285 - val_loss: 0.0951 - val_root_mean_squared_error: 0.3084
# Epoch 254/300
# 12/12 [==============================] - 3s 215ms/step - loss: 0.1079 - root_mean_squared_error: 0.3285 - val_loss: 0.0951 - val_root_mean_squared_error: 0.3083
# Epoch 255/300
# 12/12 [==============================] - 2s 211ms/step - loss: 0.1079 - root_mean_squared_error: 0.3285 - val_loss: 0.0951 - val_root_mean_squared_error: 0.3083
# Epoch 256/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1079 - root_mean_squared_error: 0.3285 - val_loss: 0.0950 - val_root_mean_squared_error: 0.3083
# Epoch 257/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1079 - root_mean_squared_error: 0.3284 - val_loss: 0.0950 - val_root_mean_squared_error: 0.3083
# Epoch 258/300
# 12/12 [==============================] - 3s 212ms/step - loss: 0.1079 - root_mean_squared_error: 0.3284 - val_loss: 0.0950 - val_root_mean_squared_error: 0.3082
# Epoch 259/300
# 12/12 [==============================] - 2s 203ms/step - loss: 0.1079 - root_mean_squared_error: 0.3284 - val_loss: 0.0950 - val_root_mean_squared_error: 0.3082
# Epoch 260/300
# 12/12 [==============================] - 2s 203ms/step - loss: 0.1079 - root_mean_squared_error: 0.3284 - val_loss: 0.0950 - val_root_mean_squared_error: 0.3082
# Epoch 261/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1079 - root_mean_squared_error: 0.3284 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3081
# Epoch 262/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1078 - root_mean_squared_error: 0.3284 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3081
# Epoch 263/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1078 - root_mean_squared_error: 0.3284 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3081
# Epoch 264/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1078 - root_mean_squared_error: 0.3284 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3080
# Epoch 265/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1078 - root_mean_squared_error: 0.3284 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3080
# Epoch 266/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1078 - root_mean_squared_error: 0.3284 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3080
# Epoch 267/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1078 - root_mean_squared_error: 0.3284 - val_loss: 0.0948 - val_root_mean_squared_error: 0.3080
# Epoch 268/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0948 - val_root_mean_squared_error: 0.3079
# Epoch 269/300
# 12/12 [==============================] - 3s 231ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0948 - val_root_mean_squared_error: 0.3079
# Epoch 270/300
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0948 - val_root_mean_squared_error: 0.3079
# Epoch 271/300
# 12/12 [==============================] - 3s 233ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0948 - val_root_mean_squared_error: 0.3079
# Epoch 272/300
# 12/12 [==============================] - 3s 239ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0948 - val_root_mean_squared_error: 0.3078
# Epoch 273/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3078
# Epoch 274/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3078
# Epoch 275/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3078
# Epoch 276/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077
# Epoch 277/300
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077
# Epoch 278/300
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077
# Epoch 279/300
# 12/12 [==============================] - 3s 224ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077
# Epoch 280/300
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1078 - root_mean_squared_error: 0.3283 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3076
# Epoch 281/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1077 - root_mean_squared_error: 0.3283 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3076
# Epoch 282/300
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3076
# Epoch 283/300
# 12/12 [==============================] - 2s 208ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3076
# Epoch 284/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3075
# Epoch 285/300
# 12/12 [==============================] - 2s 205ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3075
# Epoch 286/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3075
# Epoch 287/300
# 12/12 [==============================] - 3s 216ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3075
# Epoch 288/300
# 12/12 [==============================] - 3s 214ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3075
# Epoch 289/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074
# Epoch 290/300
# 12/12 [==============================] - 2s 200ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074
# Epoch 291/300
# 12/12 [==============================] - 2s 204ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074
# Epoch 292/300
# 12/12 [==============================] - 2s 200ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074
# Epoch 293/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074
# Epoch 294/300
# 12/12 [==============================] - 2s 203ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3073
# Epoch 295/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3073
# Epoch 296/300
# 12/12 [==============================] - 2s 209ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0944 - val_root_mean_squared_error: 0.3073
# Epoch 297/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0944 - val_root_mean_squared_error: 0.3073
# Epoch 298/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0944 - val_root_mean_squared_error: 0.3073
# Epoch 299/300
# 12/12 [==============================] - 2s 206ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0944 - val_root_mean_squared_error: 0.3073
# Epoch 300/300
# 12/12 [==============================] - 2s 207ms/step - loss: 0.1077 - root_mean_squared_error: 0.3282 - val_loss: 0.0944 - val_root_mean_squared_error: 0.3072

# %%
for item in list_for_test:
    tp = 1 #позиция оригинала
    pp = 4 #позиция предсказания
    
    #img_query_text, img_name = test_get_predict(df_tt, item, model3)
    img_name, oc, ooc = predict_ocenka(df_tt, item, model3)
    img_original = Image.open(f'source/test_images/{df_tt["image"][item]}')
    img_predict = Image.open(f'source/test_images/{img_name}')

    text_original = f'{df_tt["query_text"][item]}, orig:{ooc}'
    #text_predict = img_query_text
    text_predict = f'{img_name} pred: {oc}'

    plt.figure(figsize=(17,17))
    plt.subplot(5,4,tp);

    plt.title(text_original)
    plt.axis ('off')
    plt.imshow(img_original)

    plt.subplot(5,4,pp)
    plt.title(f'{text_predict}')
    plt.axis ('off')
    plt.imshow(img_predict);
    tp *=5
    pp *=5
# Out:
# 11/11 [==============================] - 0s 33ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 34ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 34ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 36ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 35ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 37ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 37ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 36ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 34ms/step
# '0.0000000298023223876953125'
# 11/11 [==============================] - 0s 35ms/step
# '0.0000000298023223876953125'

# %% [markdown]
# __Вывод:__ Модель ничего не предсказывает.

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера</b></font>\
# <font color='green'>Проект действительно напряжный, но большая часть пути пройдена! </font>
#
# <font color='blue'>Что можно сделать лучше:</font>
# <ul><font color='red'>1) Добавить загрузчик</font></ul>
# <ul><font color='red'>2) Убрать полносвязные слои для векторизации</font></ul>
# <ul><font color='red'>3) Добавить больше наблюдений (просмотров данных и размерностей) и выводов</font></ul>
# <ul><font color='red'>4) Описать выбор метрики</font></ul>
#
# <font color='blue'><b>Спасибо, жду твоих исправлений и комментариев!</b></font>

# %% [markdown]
# ## 8. Выводы
#
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке исполнения
# - [ ]  Исследовательский анализ данных выполнен
# - [ ]  Проверены экспертные оценки и краудсорсинговые оценки
# - [ ]  Из датасета исключены те объекты, которые выходят за рамки юридических ограничений
# - [ ]  Изображения векторизованы
# - [ ]  Текстовые запросы векторизованы
# - [ ]  Данные корректно разбиты на тренировочную и тестовую выборки
# - [ ]  Предложена метрика качества работы модели
# - [ ]  Предложена модель схожести изображений и текстового запроса
# - [ ]  Модель обучена
# - [ ]  По итогам обучения модели сделаны выводы
# - [ ]  Проведено тестирование работы модели
# - [ ]  По итогам тестирования визуально сравнили качество поиска
